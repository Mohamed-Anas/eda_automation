# %% [markdown]
# ### EDA Demo

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Demo Dataset with some data modification to show features of the tool.

# %%
df = pd.read_csv('chronic_kidney_disease.csv')

data = """05/10/2001; 05/10/01; 5/10/09; 6/2/01
May-10-2001; May 10, 2010; March 25, 2001; Mar. 25, 2001; Mar 25 2001;
25 Mar 2001; 25 March 2001; 25 Mar. 2001; 25 March, 2001
Mar 25th, 2001; Mar 25th, 2001; Mar 12nd, 2001
Feb 2001; Sep 2001; Oct 2001
5/2001; 11/2001
2001; 2015 5"""

data = data.replace('\n',';').split(';')
df['Date'] = pd.Series([data[np.random.randint(0,len(data))] for _ in range(df.shape[0])])



df['aged']=df['age']

df.rename(columns = {"aged":"age"},inplace=True)

# %%
df.head()

# %%
from dataanalyser.eda import Preprocessing,Imputation,Testing,Visual,Outlier

# %%
Preprocessing(df).automate()
# Out:
# Number of rows:  400 	 Number of columns:  27
# 		**Preprocessing**
#
# bp  converted from str to  int
# sg  converted from str to  float
# al  converted from str to  int
# su  converted from str to  int
# bgr  converted from str to  int
# bu  converted from str to  int
# sc  converted from str to  float
# hemo  converted from str to  float
# pcv  converted from str to  int
# Date  converted from str to datetime
# Number of rows:  400 	 Number of columns:  27
#
# ******************************
# 		**Columns Information**
# Note: Numeric_variables having less than 10 distinct values are regarded as categoric
# numeric :	 10
# categoric :	 14
# datetime :	 1
# problem_in_detecting_dtype :	 2
# numeric :	 ['bp', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc']
# categoric :	 ['sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'class']
# datetime :	 ['Date']
# problem_in_detecting_dtype :	 ['age', 'age']
# 		**Data Information**
# 'Data Info failed: \nProblem with Column names -- Check for duplicate column names'
# 		**Dataset**
#   age    bp     sg   al   su     rbc        pc         pcc          ba    bgr  \
# 0  48  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent  121.0
# 1   7  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent    NaN
# 2  62  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent  423.0
# 3  48  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent  117.0
# 4  51  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent  106.0
#
#    ...   rc  htn   dm  cad  appet   pe  ane  class       Date age
# 0  ...  5.2  yes  yes   no   good   no   no    ckd 2001-06-02  48
# 1  ...  NaN   no   no   no   good   no   no    ckd 2001-09-01   7
# 2  ...  NaN   no  yes   no   poor   no  yes    ckd 2001-05-01  62
# 3  ...  3.9  yes   no   no   poor  yes  yes    ckd 2001-05-10  48
# 4  ...  4.6   no   no   no   good   no   no    ckd 2001-10-01  51
#
# [5 rows x 27 columns]
# 		**Description of Numeric Variables**
#                bp          sg          al          su         bgr          bu  \
# count  388.000000  353.000000  354.000000  351.000000  356.000000  381.000000
# mean    76.469072    1.017408    1.016949    0.450142  148.036517   57.425722
# std     13.683637    0.005717    1.352679    1.099191   79.281714   50.503006
# min     50.000000    1.005000    0.000000    0.000000   22.000000    1.500000
# 25%     70.000000    1.010000    0.000000    0.000000   99.000000   27.000000
# 50%     80.000000    1.020000    0.000000    0.000000  121.000000   42.000000
# 75%     80.000000    1.020000    2.000000    0.000000  163.000000   66.000000
# max    180.000000    1.025000    5.000000    5.000000  490.000000  391.000000
#
#                sc         sod         pot        hemo         pcv  \
# count  383.000000  313.000000  312.000000  348.000000  329.000000
# mean     3.072454  137.528754    4.627244   12.526437   38.884498
# std      5.741126   10.408752    3.193904    2.912587    8.990105
# min      0.400000    4.500000    2.500000    3.100000    9.000000
# 25%      0.900000  135.000000    3.800000   10.300000   32.000000
# 50%      1.300000  138.000000    4.400000   12.650000   40.000000
# 75%      2.800000  142.000000    4.900000   15.000000   45.000000
# max     76.000000  163.000000   47.000000   17.800000   54.000000
#
#                  wc          rc
# count    294.000000  269.000000
# mean    8406.122449    4.707435
# std     2944.474190    1.025323
# min     2200.000000    2.100000
# 25%     6500.000000    3.900000
# 50%     8000.000000    4.800000
# 75%     9800.000000    5.400000
# max    26400.000000    8.000000
# 		**Description of Categoric Variables**
#         age     rbc      pc         pcc          ba  htn   dm  cad appet   pe  \
# count   400     248     335         396         396  398  398  398   399  399
# unique   77       2       2           2           2    2    3    2     2    2
# top      60  normal  normal  notpresent  notpresent   no   no   no  good   no
# freq     19     201     259         354         374  251  261  364   317  323
# first   NaN     NaN     NaN         NaN         NaN  NaN  NaN  NaN   NaN  NaN
# last    NaN     NaN     NaN         NaN         NaN  NaN  NaN  NaN   NaN  NaN
#
#         ane class                 Date  age
# count   399   400                  381  400
# unique    2     2                   13   77
# top      no   ckd  2001-03-25 00:00:00   60
# freq    339   250                  151   19
# first   NaN   NaN  2001-01-01 00:00:00  NaN
# last    NaN   NaN  2015-05-01 00:00:00  NaN
# 		**Dropping Duplicates**
#
# Duplicate rows detected:  0
# Rows removed:  0
# Columns with duplicate names
# ['age']
#     age age
# 0    48  48
# 1     7   7
# 2    62  62
# 3    48  48
# 4    51  51
# ..   ..  ..
# 395  55  55
# 396  42  42
# 397  12  12
# 398  17  17
# 399  58  58
#
# [400 rows x 2 columns]
# Drop columns with duplicate names(y or n):
# Warning: Columns Dropped  ['age']
# age  converted from str to  int
# Rows removed : 0
# Columns removed : 1
# Number of rows:  400 	 Number of columns:  26
#
# ******************************
# 		**Dropping rows**
#
# Rows having more than  30.0 %  null values are dropped
# Number of rows to be dropped:  24
# Drop rows(y or n) c to change percentage:
# Rows removed : 24
# Number of rows:  376 	 Number of columns:  26
#
# ******************************
# 		**Dropping Columns**
#
# Columns having more than  40.0 %  null values are dropped
# []
# Drop columns(y or n) c to change percentage:
# The Dropped Columns are  []
# Columns removed : 0
# Number of rows:  376 	 Number of columns:  26
#
# ******************************
# 		**Target Information**
#
# Supervised or Unsupervised Analysis:(s for supervised,u for unsupervised:

# %%
df.head()
# Out:
#      bp     sg   al   su     rbc        pc         pcc          ba    bgr  \
# 0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent  121.0
# 1  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent    NaN
# 2  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent  423.0
# 3  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent  117.0
# 4  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent  106.0
#
#      bu  ...   rc  htn   dm  cad  appet   pe  ane class       Date   age
# 0  36.0  ...  5.2  yes  yes   no   good   no   no   ckd 2001-06-02  48.0
# 1  18.0  ...  NaN   no   no   no   good   no   no   ckd 2001-09-01   7.0
# 2  53.0  ...  NaN   no  yes   no   poor   no  yes   ckd 2001-05-01  62.0
# 3  56.0  ...  3.9  yes   no   no   poor  yes  yes   ckd 2001-05-10  48.0
# 4  26.0  ...  4.6   no   no   no   good   no   no   ckd 2001-10-01  51.0
#
# [5 rows x 26 columns]

# %%
Visual(df).automate()
# Out:
# 		**Pairplot**
# Note: Numeric_variables having less than 10 distinct values are regarded as categoric

# %%
Outlier(df).automate()

# %%
Imputation(df).automate()

# %%
Testing(df).automate()
